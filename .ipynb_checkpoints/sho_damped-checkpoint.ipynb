# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# # SHO

# %%
t = np.linspace(0,15,1000)
omega_sq = 1
y = [0,1] #[x,v] for position and velocity
def harmonic(t,y):
    solution = [y[1],-omega_sq*y[0]] #where y[1] is v and y[0] is x
    return solution
sho = solve_ivp(harmonic, [0,1000], y0 = y, t_eval = t)

# %%
plt.plot(t,sho.y[0])
plt.ylabel("Position")
plt.xlabel("Time")
plt.title('SHO', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'SHO')

# %% [markdown]
# # Damped Oscillator

# %%
#Initial Conditions
t = np.linspace(0,15,1000)
y = [0,1]
gamma = 1
omega_sqr = 100
def sho(t,y):
    solution = (y[1],(-gamma*y[1]-omega_sqr*y[0]))
    return solution

# %%
solution = solve_ivp(sho, [0,1000], y0 = y, t_eval = t)

# %%
plt.plot(t,solution.y[0])
plt.ylabel("Position")
plt.xlabel("Time")
plt.title('Damped Oscillator', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Damped Oscillator')

# %% [markdown]
# # Non linear Pendulum

# %%
time = np.linspace(0,3,1000)
g = 9.8
l = 0.1
y = [160,0.095]
def pend(t,y):
    solution = (y[1],-(g/l)*np.sin(y[0]))
    return solution

# %%
solution = solve_ivp(pend, [0,100], y0 = y, t_eval = time)
plt.plot(t, solution.y[0])
plt.show()
